# %% [markdown]
# # Last Away

# %%
import matplotlib
# matplotlib.use("Qt5Agg") 
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
from scipy import signal, stats
import re
import os as os
import mne
import IPython
import seaborn as sns
import scipy
import joblib
import pickle
import statsmodels
from statsmodels import stats
from statsmodels.stats import multitest

## import custom functions
import sys
sys.path.append('/home/brooke/pacman/preprocessing/scripts')
import preproc_functions as pf
import average_tfr_functions as avg_tfr

## load rois
# %run ../../preprocessing/scripts/roi.py

# %%
# folders
raw_dir = '/home/brooke/pacman/raw_data'
preproc_dir = '/home/brooke/pacman/preprocessing'
tfr_dir = '/home/brooke/knight_server/remote/bstavel/pacman/preprocessing'

# subjects
sub_list = ['BJH021', 'BJH025', 'BJH016', 'SLCH002', 'BJH026', 'BJH027', 'BJH029', 'BJH039', 'BJH041', 'LL10', 'LL12', 'LL13', 'LL14', 'LL17', 'LL19']

# conditions
conditions = ['TrialType <= 16', 'TrialType > 16']

# %%
with open('../ieeg/last_away_average_hc.pkl', 'rb') as f:
    all_subs_hcs = pickle.load(f)

# %%
all_subs_hcs[0][0].shape
# Out:
# (80, 4001)

# %% [markdown]
# ## MFG

# %%
all_subs_average_mfgs = avg_tfr.calculate_last_away_average_subregion(sub_list, conditions, 'dlpfc', ROIs, 'mfg')

# save average #
with open('../ieeg/all_subs_last_away_average_mfg.pickle', 'wb') as f:
    pickle.dump(all_subs_average_mfgs, f)

# separate averages #
all_subs_average_mfg_escape = all_subs_average_mfgs[0]
all_subs_average_mfg_chase = all_subs_average_mfgs[1]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# ...

# %%
avg_tfr.plot_allsub_averages(all_subs_average_mfg_escape, "Average MFG Time–frequency Representation in Conflict Trials", 'average_mfg_conflict_all_subs.png', -1.5, 1.5)

# %%
avg_tfr.plot_allsub_averages(all_subs_average_mfg_chase, "Average MFG Time–frequency Representation in No-Conflict Trials", 'average_mfg_noconflict_all_subs.png', -1.5, 1.5)

# %% [markdown]
# ## OFC

# %%
all_subs_average_ofcs = avg_tfr.calculate_last_away_average(sub_list, conditions, 'ofc')

# save average #
with open('../ieeg/all_subs_last_away_average_ofc.pickle', 'wb') as f:
    pickle.dump(all_subs_average_ofcs, f)

# separate averages #
all_subs_average_ofc_escape = all_subs_average_ofcs[0]
all_subs_average_ofc_chase = all_subs_average_ofcs[1]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/last_away/ofc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/last_away/ofc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/last_away/ofc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/last_away/ofc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH026/ieeg/last_away/ofc-tfr.h5 ...
# Replacing existing metadata with 5 columns
# log transforming
# ...

# %%
avg_tfr.plot_allsub_averages(all_subs_average_ofc_escape, "Average OFC Time–frequency Representation in Conflict Trials", 'average_ofc_conflict_all_subs.png', -1.5, 1.5)

# %%
avg_tfr.plot_allsub_averages(all_subs_average_ofc_chase, "Average OFC Time–frequency Representation in No-Conflict Trials", 'average_ofc_noconflict_all_subs.png', -1.5, 1.5)

# %% [markdown]
# ## Hippocampus

# %%
# # compute average #
all_subs_average_hcs = avg_tfr.calculate_last_away_average(sub_list, conditions, 'hc')

# save average #
with open('../ieeg/all_subs_last_away_average_hc.pickle', 'wb') as f:
    pickle.dump(all_subs_average_hcs, f)

# # load average #
# with open('../ieeg/all_subs_last_away_average_ofc.pickle', 'rb') as f:
#     all_subs_average_hcs = pickle.load(f)

# separate averages #
all_subs_average_hc_conflict = all_subs_average_hcs[0]
all_subs_average_hc_noconflict = all_subs_average_hcs[1]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/last_away/hc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/last_away/hc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/last_away/hc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/last_away/hc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH027/ieeg/last_away/hc-tfr.h5 ...
# log transforming
# ...

# %%
avg_tfr.plot_allsub_averages(all_subs_average_hc_conflict, "Average Hippocampal Time–frequency Representation in Conflict Trials", 'average_hc_conflict_all_subs.png', -1.5, 1.5)

# %%
avg_tfr.plot_allsub_averages(all_subs_average_hc_noconflict, "Average Hippocampal Time–frequency Representation in No-Conflict Trials", 'average_hc_noconflict_all_subs.png', -1.5, 1.5)

# %% [markdown]
# ## Anterior Cingulate

# %%
all_subs_average_cings = avg_tfr.calculate_last_away_average(sub_list, conditions, 'cing')

# save average #
with open('../ieeg/all_subs_last_away_average_cing.pickle', 'wb') as f:
    pickle.dump(all_subs_average_cings, f)

# separate averages #
all_subs_average_cing_escape = all_subs_average_cings[0]
all_subs_average_cing_chase = all_subs_average_cings[1]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/last_away/cing-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/last_away/cing-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/last_away/cing-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/last_away/cing-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH026/ieeg/last_away/cing-tfr.h5 ...
# Replacing existing metadata with 5 columns
# log transforming
# ...

# %%
avg_tfr.plot_allsub_averages(all_subs_average_cing_escape, "Average Ant. Cingulate Time–frequency Representation in Conflict Trials", 'average_cing_conflict_all_subs.png', -1.5, 1.5)

# %%
avg_tfr.plot_allsub_averages(all_subs_average_cing_chase, "Average Ant. Cingulate Time–frequency Representation in No-Conflict Trials", 'average_cing_noconflict_all_subs.png', -1.5, 1.5)

# %% [markdown]
# ## Amygdala

# %%
all_subs_average_amygs = avg_tfr.calculate_last_away_average(sub_list, conditions, 'amyg')

# save average #
with open('../ieeg/all_subs_last_away_average_amyg.pickle', 'wb') as f:
    pickle.dump(all_subs_average_amygs, f)

# separate averages #
all_subs_average_amyg_escape = all_subs_average_amygs[0]
all_subs_average_amyg_chase = all_subs_average_amygs[1]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/last_away/amyg-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/last_away/amyg-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/last_away/amyg-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/last_away/amyg-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH026/ieeg/last_away/amyg-tfr.h5 ...
# Replacing existing metadata with 5 columns
# log transforming
# ...

# %%
avg_tfr.plot_allsub_averages(all_subs_average_amyg_escape, "Average Amygdala Time–frequency Representation in Conflict Trials", 'average_amyg_conflict_all_subs.png', -1.5, 1.5)

# %%
avg_tfr.plot_allsub_averages(all_subs_average_amyg_chase, "Average Amygdala Time–frequency Representation in No-Conflict Trials", 'average_amyg_noconflict_all_subs.png', -1.5, 1.5)

# %% [markdown]
# # Other Regions

# %% [markdown]
# ## dlPFC

# %%
all_subs_average_dlpfcs = avg_tfr.calculate_last_away_average(sub_list, conditions, 'dlpfc')

# save average #
with open('../ieeg/all_subs_last_away_average_dlpfc.pickle', 'wb') as f:
    pickle.dump(all_subs_average_dlpfcs, f)

# separate averages #
all_subs_average_dlpfc_escape = all_subs_average_dlpfcs[0]
all_subs_average_dlpfc_chase = all_subs_average_dlpfcs[1]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/last_away/dlpfc-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH026/ieeg/last_away/dlpfc-tfr.h5 ...
# Replacing existing metadata with 5 columns
# log transforming
# ...

# %%
avg_tfr.plot_allsub_averages(all_subs_average_dlpfc_escape, "Average dlPFC Time–frequency Representation in Conflict Trials", 'average_dlpfc_conflict_all_subs.png', -1.5, 1.5)

# %%
avg_tfr.plot_allsub_averages(all_subs_average_dlpfc_chase, "Average dlPFC Time–frequency Representation in No-Conflict Trials", 'average_dlpfc_noconflict_all_subs.png', -1.5, 1.5)

# %% [markdown]
# ## Insula

# %%
all_subs_average_insulas = avg_tfr.calculate_last_away_average(sub_list, conditions, 'insula')

# save average #
with open('../ieeg/all_subs_last_away_average_insula.pickle', 'wb') as f:
    pickle.dump(all_subs_average_insulas, f)

# separate averages #
all_subs_average_insula_escape = all_subs_average_insulas[0]
all_subs_average_insula_chase = all_subs_average_insulas[1]
# Out:
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH021/ieeg/last_away/insula-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH025/ieeg/last_away/insula-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH016/ieeg/last_away/insula-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/SLCH002/ieeg/last_away/insula-tfr.h5 ...
# log transforming
# z-scoring to baseline
# currently used subs: ['BJH021', 'BJH025', 'BJH016', 'SLCH002']
# Reading /home/brooke/knight_server/remote/bstavel/pacman/preprocessing/BJH026/ieeg/last_away/insula-tfr.h5 ...
# Replacing existing metadata with 5 columns
# log transforming
# ...

# %%
avg_tfr.plot_allsub_averages(all_subs_average_insula_escape, "Average Insula Time–frequency Representation in Conflict Trials", 'average_insula_conflict_all_subs.png', -1.5, 1.5)

# %%
avg_tfr.plot_allsub_averages(all_subs_average_insula_chase, "Average Insula Time–frequency Representation in No-Conflict Trials", 'average_insula_noconflict_all_subs.png', -1.5, 1.5)

# %% [markdown]
# ## EC

# %%
# all_subs_average_ecs = avg_tfr.calculate_last_away_average(sub_list, conditions, 'ec')
# all_subs_average_ec_escape = all_subs_average_ecs[0]
# all_subs_average_ec_chase = all_subs_average_ecs[1]

# %%
# avg_tfr.plot_allsub_averages(all_subs_average_ec_escape, "Average Entorhinal Cortex Time–frequency Representation in Conflict Trials", 'average_ec_conflict_all_subs.png', -1.5, 1.5)

# %%
# avg_tfr.plot_allsub_averages(all_subs_average_ec_chase, "Average Entorhinal Cortex Time–frequency Representation in No-Conflict Trials", 'average_ec_noconflict_all_subs.png', -1.5, 1.5)
